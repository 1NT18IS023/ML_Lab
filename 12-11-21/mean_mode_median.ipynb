# %%
li = [1,5,3,7,8,2,67,23,9]
li2 = [2,3,4,7,6,8,9,0,5]
print("The unsorted list is as follows :-")
for i in li:
    print(i)
    
print("\nThe sorted list is as follows:-")

for i in range (0,len(li)):
    for j in range (i,len(li)):
        if li[j]<li[i]:
            temp = li[j]
            li[j] = li[i]
            li[i] = temp
            
for i in li:
    print(i)
    
print("\nThe second list is as follows:-")
for i in li2:
    print(i)
    
    
print("\nThe sum of the two lists is :-")
for i in range(0,len(li)):
    print(li[i]+li2[i])

    
li3 = [23,45,65,87,3,4,156,456,90,77,2,90,90,1,66,90,65,156,156,5,65]
temp = li3.copy()
temp.sort()
print("\nThird list:-")
for i in temp:
    print(i)

    
#median
median = temp[int(len(temp)/2)]


#mean
mean = 0
for i in temp:
    mean += i
mean /= len(temp)


#mode
max = temp[-1] + 1
freqli = []
for i in range (0,max):
    freqli.append(0)
freq = 0
mode = 0
for i in temp:
    freqli[i]+=1
    if freqli[i]>freq:
        freq = freqli[i]
        mode = i
        
        

        
print("\nMean = "+str(mean)+"\nMedian = "+str(median)+"\nMode = "+str(mode))


    
'''
frequency = {}
max = 0
for i in temp:
    if i in frequency.keys():
        frequency[i].value+=1
        if frequency[i].value>max:
            max = frequency[i]
        
    elif :
        frequency.add(i,1)


mode_index = 0
freq = 0
for i in range (0,max):
    if mod[i]> freq :
        freq = mod[i]
        mode_index = i
'''
# Out:
# The unsorted list is as follows :-
# 1
# 5
# 3
# 7
# 8
# 2
# 67
# 23
# 9
#
# The sorted list is as follows:-
# 1
# 2
# 3
# 5
# 7
# 8
# 9
# 23
# 67
#
# The second list is as follows:-
# 2
# 3
# 4
# 7
# 6
# 8
# 9
# 0
# 5
#
# The sum of the two lists is :-
# 3
# 5
# 7
# 12
# 13
# 16
# 18
# 23
# 72
#
# Third list:-
# 1
# 2
# 3
# 4
# 5
# 23
# 45
# 65
# 65
# 65
# 66
# 77
# 87
# 90
# 90
# 90
# 90
# 156
# 156
# 156
# 456
#
# Mean = 85.33333333333333
# Median = 66
# Mode = 90
# '\n\nmode_index = 0\nfreq = 0\nfor i in range (0,max):\n    if mod[i]> freq :\n        freq = mod[i]\n        mode_index = i\n'
